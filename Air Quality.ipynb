# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\venka'

# %%
os.chdir('C:/Users/venka/OneDrive/Desktop/Data Sets')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\venka\\OneDrive\\Desktop\\Data Sets'

# %%
import numpy as np
import pandas as pd
data1=pd.read_csv('airquality.csv')

# %%
data1
# Out:
#      Ozone  Solar.R  Wind  Temp  Month  Day
# 0     41.0    190.0   7.4    67      5    1
# 1     36.0    118.0   8.0    72      5    2
# 2     12.0    149.0  12.6    74      5    3
# 3     18.0    313.0  11.5    62      5    4
# 4      NaN      NaN  14.3    56      5    5
# 5     28.0      NaN  14.9    66      5    6
# 6     23.0    299.0   8.6    65      5    7
# 7     19.0     99.0  13.8    59      5    8
# 8      8.0     19.0  20.1    61      5    9
# 9      NaN    194.0   8.6    69      5   10
# 10     7.0      NaN   6.9    74      5   11
# 11    16.0    256.0   9.7    69      5   12
# 12    11.0    290.0   9.2    66      5   13
# 13    14.0    274.0  10.9    68      5   14
# 14    18.0     65.0  13.2    58      5   15
# 15    14.0    334.0  11.5    64      5   16
# 16    34.0    307.0  12.0    66      5   17
# 17     6.0     78.0  18.4    57      5   18
# 18    30.0    322.0  11.5    68      5   19
# 19    11.0     44.0   9.7    62      5   20
# ...

# %%
import matplotlib.pyplot as plt

# %%
data1['Wind'].value_counts()
# Out:
# 11.5    15
# 9.7     11
# 10.3    11
# 8.0     11
# 7.4     10
# 6.9      9
# 14.9     8
# 10.9     8
# 9.2      8
# 8.6      8
# 6.3      8
# 14.3     6
# 13.8     5
# 12.0     4
# 4.6      4
# 12.6     3
# 16.6     3
# 15.5     3
# 5.7      3
# 5.1      3
# 13.2     2
# 2.3      1
# 3.4      1
# 20.7     1
# 16.1     1
# 18.4     1
# 2.8      1
# 20.1     1
# 4.1      1
# 4.0      1
# 1.7      1
# Name: Wind, dtype: int64

# %%
data1['Temp'].value_counts()
# Out:
# 81    11
# 76     9
# 82     9
# 86     7
# 77     7
# 78     6
# 79     6
# 80     5
# 87     5
# 85     5
# 84     5
# 73     5
# 92     5
# 75     4
# 68     4
# 74     4
# 67     4
# 83     4
# 61     3
# 66     3
# 57     3
# 88     3
# 72     3
# 71     3
# 69     3
# 90     3
# 93     3
# 64     2
# 59     2
# 65     2
# 89     2
# 58     2
# 94     2
# 91     2
# 62     2
# 97     1
# 63     1
# 70     1
# 96     1
# 56     1
# Name: Temp, dtype: int64

# %%
data1.apply(lambda x:sum(x.isnull()),axis=0)
# Out:
# Ozone      37
# Solar.R     7
# Wind        0
# Temp        0
# Month       0
# Day         0
# dtype: int64

# %%
#filling the missing values
#ozone is numerical so fill the missing values with mean
#replaces all numerical missing values at once
from sklearn.preprocessing import Imputer
imputer=Imputer(missing_values='NaN',strategy='mean',axis=0)

# %%
imputer
# Out:
# Imputer(axis=0, copy=True, missing_values='NaN', strategy='mean', verbose=0)

# %%
# seperating targets and inputs
features=data1.iloc[:,[2,3]]

# %%
features
# Out:
#      Wind  Temp
# 0     7.4    67
# 1     8.0    72
# 2    12.6    74
# 3    11.5    62
# 4    14.3    56
# 5    14.9    66
# 6     8.6    65
# 7    13.8    59
# 8    20.1    61
# 9     8.6    69
# 10    6.9    74
# 11    9.7    69
# 12    9.2    66
# 13   10.9    68
# 14   13.2    58
# 15   11.5    64
# 16   12.0    66
# 17   18.4    57
# 18   11.5    68
# 19    9.7    62
# 20    9.7    59
# 21   16.6    73
# 22    9.7    61
# 23   12.0    61
# 24   16.6    57
# 25   14.9    58
# 26    8.0    57
# 27   12.0    67
# 28   14.9    81
# 29    5.7    79
# ..    ...   ...
# 123   6.9    91
# 124   5.1    92
# 125   2.8    93
# 126   4.6    93
# 127   7.4    87
# 128  15.5    84
# 129  10.9    80
# 130  10.3    78
# 131  10.9    75
# 132   9.7    73
# 133  14.9    81
# 134  15.5    76
# 135   6.3    77
# 136  10.9    71
# 137  11.5    71
# 138   6.9    78
# 139  13.8    67
# 140  10.3    76
# 141  10.3    68
# 142   8.0    82
# 143  12.6    64
# 144   9.2    71
# 145  10.3    81
# ...

# %%
labels=data1.iloc[:,0:1].values

# %%
labels
# Out:
# array([[  41.],
#        [  36.],
#        [  12.],
#        [  18.],
#        [  nan],
#        [  28.],
#        [  23.],
#        [  19.],
#        [   8.],
#        [  nan],
#        [   7.],
#        [  16.],
#        [  11.],
#        [  14.],
#        [  18.],
#        [  14.],
#        [  34.],
#        [   6.],
#        [  30.],
#        [  11.],
#        [   1.],
#        [  11.],
#        [   4.],
#        [  32.],
#        [  nan],
#        [  nan],
#        [  nan],
#        [  23.],
#        [  45.],
#        [ 115.],
#        [  37.],
#        [  nan],
#        [  nan],
#        [  nan],
#        [  nan],
#        [  nan],
#        [  nan],
#        [  29.],
#        [  nan],
#        [  71.],
#        [  39.],
#        [  nan],
#        [  nan],
#        [  23.],
#        [  nan],
#        [  nan],
#        [  21.],
#        [  37.],
#        [  20.],
#        [  12.],
#        [  13.],
#        [  nan],
#        [  nan],
#        [  nan],
#        [  nan],
# ...

# %%
#replaces all numerical missing values at once
from sklearn.preprocessing import Imputer
imputer=Imputer(missing_values='NaN',strategy='mean',axis=0)

# %%
imputer
# Out:
# Imputer(axis=0, copy=True, missing_values='NaN', strategy='mean', verbose=0)

# %%
imputer.fit(labels[:,0])
labels[:,0]=imputer.fit_transform(labels[:,0])
df1=pd.DataFrame(labels)
df1.apply(lambda x:sum(x.isnull()),axis=0)
# Out:
# C:\Users\venka\Anaconda3\lib\site-packages\sklearn\utils\validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Users\venka\Anaconda3\lib\site-packages\sklearn\utils\validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Users\venka\Anaconda3\lib\site-packages\sklearn\utils\validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
# ...

# %%
o1=data1["Ozone"].mean()

# %%
o1
# Out:
# 42.12931034482759

# %%
data1["Ozone"].fillna(o1,inplace=True)

# %%
data1.apply(lambda x:sum(x.isnull()),axis=0)
# Out:
# Ozone      0
# Solar.R    7
# Wind       0
# Temp       0
# Month      0
# Day        0
# dtype: int64

# %%
data1
# Out:
#          Ozone  Solar.R  Wind  Temp  Month  Day
# 0     41.00000    190.0   7.4    67      5    1
# 1     36.00000    118.0   8.0    72      5    2
# 2     12.00000    149.0  12.6    74      5    3
# 3     18.00000    313.0  11.5    62      5    4
# 4     42.12931      NaN  14.3    56      5    5
# 5     28.00000      NaN  14.9    66      5    6
# 6     23.00000    299.0   8.6    65      5    7
# 7     19.00000     99.0  13.8    59      5    8
# 8      8.00000     19.0  20.1    61      5    9
# 9     42.12931    194.0   8.6    69      5   10
# 10     7.00000      NaN   6.9    74      5   11
# 11    16.00000    256.0   9.7    69      5   12
# 12    11.00000    290.0   9.2    66      5   13
# 13    14.00000    274.0  10.9    68      5   14
# 14    18.00000     65.0  13.2    58      5   15
# 15    14.00000    334.0  11.5    64      5   16
# 16    34.00000    307.0  12.0    66      5   17
# 17     6.00000     78.0  18.4    57      5   18
# 18    30.00000    322.0  11.5    68      5   19
# ...

# %%
x=features
y=labels

# %%
from sklearn import linear_model as lm
model=lm.LinearRegression()
results=model.fit(x,y)

# %%
predictions=model.predict(x)

# %%
accuracy=model.score(x,y)
print('Accuracy of the model:',accuracy)
# Out:
# Accuracy of the model: 0.451015419872

# %%
plt.scatter(y,predictions)

# %%
#split data
from sklearn.cross_validation import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=1)

# %%
x_train
# Out:
#      Wind  Temp
# 28   14.9    81
# 51    6.3    77
# 109   7.4    76
# 66   10.9    83
# 17   18.4    57
# 119   9.7    97
# 126   4.6    93
# 132   9.7    73
# 73   14.9    81
# 18   11.5    68
# 48    9.2    65
# 4    14.3    56
# 45   11.5    79
# 75   14.3    80
# 39   13.8    90
# 36   14.3    79
# 118   5.7    88
# 141  10.3    68
# 108   6.3    79
# 12    9.2    66
# 148   6.9    70
# 84    8.6    86
# 123   6.9    91
# 136  10.9    71
# 11    9.7    69
# 114  12.6    75
# 2    12.6    74
# 105   9.7    80
# 6     8.6    65
# 0     7.4    67
# ..    ...   ...
# 13   10.9    68
# 88    7.4    88
# 8    20.1    61
# 81    6.9    74
# 60    8.0    83
# 128  15.5    84
# 1     8.0    72
# 57   10.3    73
# 22    9.7    61
# 61    4.1    84
# 63    9.2    81
# 7    13.8    59
# 86    8.6    82
# 96    7.4    85
# 68    6.3    92
# 50   10.3    76
# 139  13.8    67
# 101   8.6    92
# 20    9.7    59
# 25   14.9    58
# 134  15.5    76
# 71    8.6    82
# 129  10.9    80
# ...

# %%
x_test
# Out:
#      Wind  Temp
# 59   14.9    77
# 33   16.1    67
# 69    5.7    92
# 127   7.4    87
# 31    8.6    78
# 107  10.3    77
# 97    4.6    87
# 14   13.2    58
# 53    4.6    76
# 44   13.8    80
# 147  16.6    63
# 138   6.9    78
# 78    6.3    84
# 102  11.5    86
# 5    14.9    66
# 85    8.0    85
# 16   12.0    66
# 100   8.0    90
# 89    7.4    86
# 95    6.9    86
# 91    9.2    81
# 124   5.1    92
# 92    6.9    81
# 99   10.3    90
# 93   13.8    81
# 40   11.5    87
# 29    5.7    79
# 42    9.2    92
# 54    6.3    76
# 122   6.3    94
# 35    8.6    85
# 19    9.7    62
# 113  14.3    72
# 103  11.5    86
# 77   10.3    82
# 145  10.3    81
# 58   11.5    80
# 121   6.3    96
# 56    8.0    78

# %%
y_train
# Out:
# array([[  45.        ],
#        [  42.12931034],
#        [  23.        ],
#        [  40.        ],
#        [   6.        ],
#        [  76.        ],
#        [  91.        ],
#        [  24.        ],
#        [  27.        ],
#        [  30.        ],
#        [  20.        ],
#        [  42.12931034],
#        [  42.12931034],
#        [   7.        ],
#        [  71.        ],
#        [  42.12931034],
#        [  42.12931034],
#        [  24.        ],
#        [  59.        ],
#        [  11.        ],
#        [  30.        ],
#        [  80.        ],
#        [  96.        ],
#        [   9.        ],
#        [  16.        ],
#        [  42.12931034],
#        [  12.        ],
#        [  65.        ],
#        [  23.        ],
#        [  41.        ],
#        [  44.        ],
#        [  64.        ],
#        [  42.12931034],
#        [  28.        ],
#        [  28.        ],
#        [  21.        ],
#        [  49.        ],
#        [  42.12931034],
# ...

# %%
y_test
# Out:
# array([[  42.12931034],
#        [  42.12931034],
#        [  97.        ],
#        [  47.        ],
#        [  42.12931034],
#        [  22.        ],
#        [  66.        ],
#        [  18.        ],
#        [  42.12931034],
#        [  42.12931034],
#        [  14.        ],
#        [  46.        ],
#        [  61.        ],
#        [  42.12931034],
#        [  28.        ],
#        [ 108.        ],
#        [  34.        ],
#        [ 110.        ],
#        [  50.        ],
#        [  78.        ],
#        [  59.        ],
#        [  78.        ],
#        [  39.        ],
#        [  89.        ],
#        [   9.        ],
#        [  39.        ],
#        [ 115.        ],
#        [  42.12931034],
#        [  42.12931034],
#        [  85.        ],
#        [  42.12931034],
#        [  11.        ],
#        [   9.        ],
#        [  44.        ],
#        [  35.        ],
#        [  36.        ],
#        [  42.12931034],
#        [  84.        ],
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.scatter(y,predictions)

# %%
#evaluating the model
from sklearn.metrics import mean_squared_error,r2_score

# %%
print('Slope:',model.coef_)
print('intercept:',model.intercept_)
print("\n")
# Out:
# Slope: [[-2.59864254  1.4023871 ]]
# intercept: [-41.21587132]

# %%
import numpy as np
rmse=(np.sqrt(mean_squared_error(y,predictions)))
r2=r2_score(y,predictions)

# %%
print("The model performance")
print("--------------------------")
print("RMSE is {}".format(rmse))
print("R2 score is {}".format(r2))
print("\n")
# Out:
# The model performance
# --------------------------
# RMSE is 21.19033113451243
# R2 score is 0.45101541987219373
